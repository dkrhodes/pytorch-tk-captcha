# %%
# pip3 install matplotlib
# pip3 install opencv-python

from os import path
image_dir = "1108/f24144eb9039fa7b197d92762ee9d945c5ed1df4_73/"
bg_path = path.join(image_dir, "bg.jpg")
cut_path = path.join(image_dir, 'cut.jpg')

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image, ImageDraw
import random

# 打开 bg 和 cut 图片
bg = Image.open(bg_path)
cut = Image.open(cut_path)

cut = cut.rotate(-130, expand=False)

# 将 cut 图片裁剪成圆形
mask = Image.new("L", cut.size, 0)
draw = ImageDraw.Draw(mask)
draw.ellipse((0, 0, cut.size[0], cut.size[1]), fill=255)
cut.putalpha(mask)

# 将 cut 图片复制到 bg 中央
bg.paste(cut, (bg.size[0]//2 - cut.size[0]//2, bg.size[1]//2 - cut.size[1]//2), cut)

plt.imshow(bg)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 48
#      45     with open('angle.txt', 'w') as f:
#      46         f.write(str(angle))
# ---> 48 split_img(bg)
#
# Cell In[20], line 23, in split_img(image)
#      22 def split_img(image):
# ---> 23     size = image.shape[0]
#      24     center = (size//2, size//2)
#      25     radius = 221//2
#
# File /opt/homebrew/lib/python3.10/site-packages/PIL/Image.py:529, in Image.__getattr__(self, name)
#     527     deprecate("Image categories", 10, "is_animated", plural=True)
#     528     return self._category
# --> 529 raise AttributeError(name)
#
# AttributeError: shape

# %%
import cv2
import numpy as np

bg = cv2.imread(bg_path, cv2.IMREAD_COLOR)
cut = cv2.imread(cut_path, cv2.IMREAD_COLOR)

def show_img(img):
    plt.imshow(img)
    plt.show()

def rotate_and_combine_img(angle):
    # 旋转角度
    M = cv2.getRotationMatrix2D((cut.shape[1]/2, cut.shape[0]/2), angle, 1)
    cut_o = cv2.warpAffine(cut, M, (cut.shape[1], cut.shape[0]))
    #cut_o = cv2.resize(cut_o, (cut_o.shape[1], cut_o.shape[0]))
    
    # 扩展小图片画布
    cut_new = np.zeros(bg.shape, np.uint8)
    center = (int(cut_new.shape[1]/2), int(cut_new.shape[0]/2))
    x = center[0] - int(cut_o.shape[1]/2)
    y = center[1] - int(cut_o.shape[0]/2)
    cut_new[y:y+cut_o.shape[0], x-1:x+cut_o.shape[1]-1] = cut_o
    
    bg_h, bg_w = bg.shape[:2]
    cut_h, cut_w = cut_o.shape[:2]
    bg_center = (int(bg_w/2), int(bg_h/2))
    
    # 制作掩盖层
    mask = np.zeros((bg_h, bg_w), dtype=np.uint8)
    cv2.circle(mask, bg_center, cut_h//2+2, (255, 255, 255), -1)
    mask2 = np.zeros((bg_h, bg_w), dtype=np.uint8)
    cv2.circle(mask2, bg_center, bg_h//2//2, (255, 255, 255), -1)
    
    # 掩盖小图片的外圈
    cut_fg = cv2.bitwise_and(cut_new, cut_new, mask=mask)
    # 掩盖大图片的中心圈
    bg_bg = cv2.bitwise_and(bg, bg, mask=cv2.bitwise_not(mask2))

    new_image = cv2.add(cut_fg, bg_bg)
    #new_image = cv2.add(new_image, cut_fg)
    #new_image = cv2.add(new_image, cut_bg)
    return new_image
        
rotated_img = rotate_and_combine_img(101)
show_img(rotated_img)

def rotate_img(img, angle):
    M = cv2.getRotationMatrix2D((cut.shape[1]/2, cut.shape[0]/2), angle, 1)
    return cv2.warpAffine(cut, M, (cut.shape[1], cut.shape[0]))

def rotate_save(path, angle, dest):
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    rotated = rotate_img(img, 259)

# %%
import cv2
import numpy as np
import random
import time

random.seed(time.time())

bg = cv2.imread(bg_path, cv2.IMREAD_COLOR)
cut = cv2.imread(cut_path, cv2.IMREAD_COLOR)

def show_angle(angle):
    # 旋转角度
    M = cv2.getRotationMatrix2D((cut.shape[1]/2, cut.shape[0]/2), angle, 1)
    cut_o = cv2.warpAffine(cut, M, (cut.shape[1], cut.shape[0]))
    # 扩展小图片画布
    cut_new = np.zeros(bg.shape, np.uint8)
    center = (int(cut_new.shape[1]/2), int(cut_new.shape[0]/2))
    x = center[0] - int(cut.shape[1]/2)
    y = center[1] - int(cut.shape[0]/2)
    cut_new[y:y+cut.shape[0], x:x+cut.shape[1]] = cut_o
    
    bg_h, bg_w = bg.shape[:2]
    cut_h, cut_w = cut_o.shape[:2]
    bg_center = (int(bg_w/2), int(bg_h/2))
    
    # 制作掩盖层
    mask = np.zeros((bg_h, bg_w), dtype=np.uint8)
    cv2.circle(mask, bg_center, cut_h//2, (255, 255, 255), -1)
    
    # 掩盖小图片的外圈
    cut_fg = cv2.bitwise_and(cut_new, cut_new, mask=mask)
    # 掩盖大图片的中心圈
    bg_bg = cv2.bitwise_and(bg, bg, mask=cv2.bitwise_not(mask))
    cut_fg = cv2.Canny(cut_fg, t1, t2)
    bg_bg = cv2.Canny(bg_bg, t1, t2)

    new_image = cv2.add(cut_fg, bg_bg)
    #new_image = cv2.add(new_image, cut_fg)
    #new_image = cv2.add(new_image, cut_bg)

    plt.imshow(new_image, cmap = plt.cm.gray)
    plt.show()
    
t1 = 50
t2 = 100

show_angle(281)
